# %% [markdown]
# A subtraction

# %%
a=15
b=6
c=5
sub2=a-b
sub3=a-b-c
print(sub2)
print(sub3)
# Out:
# 9
# 4

# %% [markdown]
# B multiplication

# %%
a=3
b=5
mul=a*b
print(mul)
# Out:
# 15

# %% [markdown]
# C division

# %%
a=20
b=4
quotient=a/b
remainder=a%b
print(quotient)
print(remainder)
# Out:
# 5.0
# 0

# %% [markdown]
# D squaring of numbers

# %%
a=4
square=a**2
print(square)
# Out:
# 16

# %% [markdown]
# E square root

# %%
a=9
root=a**(1/2)
print(root)
# Out:
# 3.0

# %% [markdown]
# (a+b)^2

# %%
a=2
b=3
soln=(a+b)**2
print(soln)
# Out:
# 25
